# %%
import pandas as pd

data = {
    "date": pd.date_range(start="2024-01-01", periods=30, freq='D'),
    "sales": [100,120,130,90,95,110,150,145,160,155,
              140,120,115,100,90,105,130,135,125,140,
              150,160,170,180,175,165,155,150,145,140]
}

df = pd.DataFrame(data)
df.to_csv("sales.csv", index=False)

df.head()
# Out:
#         date  sales
# 0 2024-01-01    100
# 1 2024-01-02    120
# 2 2024-01-03    130
# 3 2024-01-04     90
# 4 2024-01-05     95

# %%
import pandas as pd

df = pd.read_csv("sales.csv")
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    30 non-null     object
#  1   sales   30 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 612.0+ bytes
# None
#             sales
# count   30.000000
# mean   134.833333
# std     25.847141
# min     90.000000
# 25%    116.250000
# 50%    140.000000
# 75%    153.750000
# max    180.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(df['date'], df['sales'], marker='o')
plt.title("Daily Sales")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sales = [100, 200, 150, 250, 300]

# 1. Print first and last value
print(sales[0], sales[-1])

# 2. Loop through all values
for s in sales:
    print("Sale:", s)

# 3. Create a function to convert sales to revenue with 10% tax
def add_tax(x):
    return (x*1.1)


print(add_tax(200))
# Out:
# 100 300
# Sale: 100
# Sale: 200
# Sale: 150
# Sale: 250
# Sale: 300
# 220.00000000000003

# %%
import pandas as pd

df = pd.read_csv("sales.csv")
df.head()
# Out:
#          date  sales
# 0  2024-01-01    100
# 1  2024-01-02    120
# 2  2024-01-03    130
# 3  2024-01-04     90
# 4  2024-01-05     95

# %%
df['sales']
# Out:
# 0     100
# 1     120
# 2     130
# 3      90
# 4      95
# 5     110
# 6     150
# 7     145
# 8     160
# 9     155
# 10    140
# 11    120
# 12    115
# 13    100
# 14     90
# 15    105
# 16    130
# 17    135
# 18    125
# 19    140
# 20    150
# 21    160
# 22    170
# 23    180
# 24    175
# 25    165
# 26    155
# 27    150
# 28    145
# 29    140
# Name: sales, dtype: int64

# %%
df['double_sales'] = df['sales'] * 2
df.head()
# Out:
#          date  sales  double_sales
# 0  2024-01-01    100           200
# 1  2024-01-02    120           240
# 2  2024-01-03    130           260
# 3  2024-01-04     90           180
# 4  2024-01-05     95           190

# %%
df['date'] = pd.to_datetime(df['date'])
print(df['date'])
# Out:
# 0    2024-01-01
# 1    2024-01-02
# 2    2024-01-03
# 3    2024-01-04
# 4    2024-01-05
# 5    2024-01-06
# 6    2024-01-07
# 7    2024-01-08
# 8    2024-01-09
# 9    2024-01-10
# 10   2024-01-11
# 11   2024-01-12
# 12   2024-01-13
# 13   2024-01-14
# 14   2024-01-15
# 15   2024-01-16
# 16   2024-01-17
# 17   2024-01-18
# 18   2024-01-19
# 19   2024-01-20
# 20   2024-01-21
# 21   2024-01-22
# 22   2024-01-23
# 23   2024-01-24
# 24   2024-01-25
# 25   2024-01-26
# 26   2024-01-27
# 27   2024-01-28
# 28   2024-01-29
# 29   2024-01-30
# Name: date, dtype: datetime64[ns]

# %%
df[df['sales'] > 150]
df.sort_values('sales', ascending=False)
# Out:
#          date  sales  double_sales
# 23 2024-01-24    180           360
# 24 2024-01-25    175           350
# 22 2024-01-23    170           340
# 25 2024-01-26    165           330
# 8  2024-01-09    160           320
# 21 2024-01-22    160           320
# 26 2024-01-27    155           310
# 9  2024-01-10    155           310
# 20 2024-01-21    150           300
# 27 2024-01-28    150           300
# 6  2024-01-07    150           300
# 7  2024-01-08    145           290
# 28 2024-01-29    145           290
# 10 2024-01-11    140           280
# 29 2024-01-30    140           280
# 19 2024-01-20    140           280
# 17 2024-01-18    135           270
# 2  2024-01-03    130           260
# 16 2024-01-17    130           260
# 18 2024-01-19    125           250
# 11 2024-01-12    120           240
# 1  2024-01-02    120           240
# 12 2024-01-13    115           230
# 5  2024-01-06    110           220
# 15 2024-01-16    105           210
# 0  2024-01-01    100           200
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
plt.plot(df['date'], df['sales'])
plt.show()
